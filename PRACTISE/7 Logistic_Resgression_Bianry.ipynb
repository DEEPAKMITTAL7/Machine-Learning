# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('insurance_data.csv')
data
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
'''Till now in our learning we have came accross the continous values and we used Lnear Regression for the same.
Eg:
Weather, Stock, Homeprices

Now we will learn to work on categorical values using Logistic Regression.
Eg:
Voting Rights, Insurance Validity, Citizenship, Spam Email. 

The person is going to vote for :
BJP
CONGRESS
OTHERS

So prevously the data could be linear but here we need the categorical exact data mapping
'''
# Out:
# 'Till now in our learning we have came accross the continous values and we used Lnear Regression for the same.\nEg:\nWeather, Stock, Homeprices\n\nNow we will learn to work on categorical values using Logistic Regression.\nEg:\nVoting Rights, Insurance Validity, Citizenship, Spam Email. \n\nThe person is going to vote for :\nBJP\nCONGRESS\nOTHERS\n\nSo prevously the data could be linear but here we need the categorical exact data mapping\n'

# %%
'''

Logistic Regression is used for Classification. or in lamen -> decision making/ occurance of an event 

1. Binary -> 

Will customer buy insurance or not?
Yes/No

2. Multiclass

The person is going to vote for :
BJP
CONGRESS
OTHERS

'''
# Out:
# '\n\nLogistic Regression is used for Classification. or in lamen -> decision making/ occurance of an event \n\n1. Binary -> \n\nWill customer buy insurance or not?\nYes/No\n\n2. Multiclass\n\nThe person is going to vote for :\nBJP\nCONGRESS\nOTHERS\n\n'

# %%
plt.scatter(data['age'],data['bought_insurance'],marker='*')

# %%
'''
sigmoid function will come handy here 

sigmoid(z) = 1
           ---------- or  1 / (1 + math.pow(e,-z))
                -z
           1 + e
           
           
This function converts input into range 0 to 1.

e = Euler's number = 2.71828

Hence,
y = mx+b 

and z is y

1 / (1 + math.pow(e,-(mx+b)))

But sklearn does everything does everything for us.

'''
# Out:
# "\nsigmoid function will come handy here \n\nsigmoid(z) = 1\n           ---------- or  1 / (1 + math.pow(e,-z))\n                -z\n           1 + e\n           \n           \nThis function converts input into range 0 to 1.\n\ne = Euler's number = 2.71828\n\nHence,\ny = mx+b \n\nand z is y\n\n1 / (1 + math.pow(e,-(mx+b)))\n\nBut sklearn does everything does everything for us.\n\n"

# %%
# No we have learn train_test_split so we are going to use it here.

# %%
data.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['age']]
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y = data[['bought_insurance']]
y
# Out:
#     bought_insurance
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# 5                  1
# 6                  0
# 7                  1
# 8                  1
# 9                  1
# 10                 0
# 11                 0
# 12                 0
# 13                 0
# 14                 1
# 15                 1
# 16                 1
# 17                 1
# 18                 0
# 19                 0
# 20                 0
# 21                 0
# 22                 1
# 23                 1
# 24                 1
# 25                 1
# 26                 0

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
y_train
# Out:
#     bought_insurance
# 23                 1
# 13                 0
# 19                 0
# 20                 0
# 16                 1
# 1                  0
# 10                 0
# 26                 0
# 25                 1
# 8                  1
# 6                  0
# 4                  1
# 18                 0
# 9                  1
# 7                  1
# 22                 1
# 3                  0
# 0                  0
# 21                 0
# 15                 1
# 12                 0

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, 1, 1, 0], dtype=int64)

# %%
y_test
# Out:
#     bought_insurance
# 2                  1
# 24                 1
# 14                 1
# 17                 1
# 5                  1
# 11                 0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
# NOW LETS CHECK THE PROBABILITY OF PERSON BUYING THE INSURANCE

# %%
model.predict_proba(x_test)
# Out:
# array([[0.34030833, 0.65969167],
#        [0.26925593, 0.73074407],
#        [0.2918862 , 0.7081138 ],
#        [0.13059794, 0.86940206],
#        [0.15824269, 0.84175731],
#        [0.81292397, 0.18707603]])

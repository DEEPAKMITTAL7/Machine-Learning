# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = sns.load_dataset('tips')
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2 = pd.read_csv('ece.csv')
df2
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1           ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2           ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 16025       ECTQ.S4AXP  2018.03        47.2         NaN      F  Percent
# 16026       ECTQ.S4AXP  2018.06        48.6         NaN      F  Percent
# 16027       ECTQ.S4AXP  2018.09        48.2         NaN      F  Percent
# 16028       ECTQ.S4AXP  2018.12        46.6         NaN      F  Percent
# 16029       ECTQ.S4AXP  2019.03        45.8         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 0              6  Electronic Card Transactions (ANZSIC06) - ECT
# 1              6  Electronic Card Transactions (ANZSIC06) - ECT
# 2              6  Electronic Card Transactions (ANZSIC06) - ECT
# 3              6  Electronic Card Transactions (ANZSIC06) - ECT
# 4              6  Electronic Card Transactions (ANZSIC06) - ECT
# ...          ...                                            ...
# 16025          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16026          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16027          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16028          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16029          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 0      Total values - Electronic card transactions A/...         Actual
# 1      Total values - Electronic card transactions A/...         Actual
# 2      Total values - Electronic card transactions A/...         Actual
# 3      Total values - Electronic card transactions A/...         Actual
# 4      Total values - Electronic card transactions A/...         Actual
# ...                                                  ...            ...
# 16025  Electronic card transactions by mean and propo...         Actual
# 16026  Electronic card transactions by mean and propo...         Actual
# 16027  Electronic card transactions by mean and propo...         Actual
# 16028  Electronic card transactions by mean and propo...         Actual
# 16029  Electronic card transactions by mean and propo...         Actual
#
#                                           Series_title_2  Series_title_3  \
# 0                                   RTS total industries             NaN
# 1                                   RTS total industries             NaN
# 2                                   RTS total industries             NaN
# 3                                   RTS total industries             NaN
# 4                                   RTS total industries             NaN
# ...                                                  ...             ...
# 16025  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16026  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16027  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16028  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16029  Debit card usage as a proportion of total ECT ...  Proportion (%)
#
#        Series_title_4  Series_title_5
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 16025             NaN             NaN
# 16026             NaN             NaN
# 16027             NaN             NaN
# 16028             NaN             NaN
# 16029             NaN             NaN
#
# [16030 rows x 14 columns]

# %%
x1 = np.random.rand(100,5)
x2 = np.random.rand(10,5)

# %%
df3 = pd.DataFrame(x1,columns=['a','b','c','d','e'])
df3
# Out:
#            a         b         c         d         e
# 0   0.321286  0.159051  0.817008  0.111409  0.419844
# 1   0.758319  0.966139  0.534189  0.587943  0.577518
# 2   0.003143  0.502070  0.454361  0.101544  0.165602
# 3   0.770171  0.174998  0.599356  0.207710  0.691758
# 4   0.862645  0.647406  0.821211  0.410618  0.480734
# ..       ...       ...       ...       ...       ...
# 95  0.018776  0.152172  0.811173  0.988367  0.181263
# 96  0.302668  0.921184  0.872134  0.072166  0.548296
# 97  0.073508  0.474678  0.035849  0.060158  0.208311
# 98  0.067909  0.646428  0.378876  0.638473  0.666545
# 99  0.659584  0.914531  0.767810  0.389304  0.501647
#
# [100 rows x 5 columns]

# %%
df4 =pd.DataFrame(x2,columns=['a','b','c','d','e'])
df4
# Out:
#           a         b         c         d         e
# 0  0.023477  0.378566  0.968634  0.104610  0.378243
# 1  0.100608  0.790783  0.683171  0.667124  0.848657
# 2  0.355420  0.681067  0.775874  0.276737  0.792761
# 3  0.461884  0.768617  0.192481  0.332562  0.138780
# 4  0.756181  0.097826  0.462306  0.018244  0.986859
# 5  0.130704  0.811169  0.468154  0.134507  0.800734
# 6  0.568370  0.571617  0.026211  0.726394  0.860212
# 7  0.486443  0.061716  0.226449  0.555085  0.820565
# 8  0.937214  0.386745  0.871142  0.514693  0.703777
# 9  0.653208  0.511440  0.387970  0.857655  0.888155

# %%
df3.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df4.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1.plot.scatter(x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3['a'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>],
#        [<AxesSubplot:title={'center':'e'}>, <AxesSubplot:>]], dtype=object)

# %%
df4['a'].hist()
# Out:
# <AxesSubplot:>

# %%
df4['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df4.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df4.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df4.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df3.plot.hexbin(x='a',y='b',gridsize=10)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
